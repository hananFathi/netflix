# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
shows = pd.read_csv('netflix_titles.csv')

# %%
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
shows.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
shows.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
shows.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
shows['director'].fillna('Unknown', inplace=True)

# %%
shows['cast'].fillna('Unknown', inplace=True)

# %%
shows['country'].fillna('Unknown', inplace=True)

# %%
shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
shows.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
from datetime import datetime
shows['date_added'] = pd.to_datetime(shows['date_added'], format='%B %d, %Y', errors='coerce')

# %%
shows.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
shows=shows.dropna(subset=['date_added'])
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
shows=shows.dropna(subset=['rating'])
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
shows=shows.dropna(subset=['duration'])
shows
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
shows.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ### Distribution of 'type' (movies vs Tv shows)

# %%
type_distribution = shows['type'].value_counts(normalize=True)*100
plt.figure(figsize=(6,4))
type_distribution.plot(kind='bar',color=['blue','orange'])
plt.title('Distribution of Content Type')
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Year

# %%
plt.figure(figsize=(10,6))
shows['release_year'].hist(bins=30,color='skyblue',edgecolor='black')
plt.title('Distribution of Release Years')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of Rating

# %%
rating_distribution = shows['rating'].value_counts(normalize=True)*100
plt.figure(figsize=(10,6))
rating_distribution.plot(kind='bar',color='green')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# ### Distribution of Content by Country

# %%
country_distribution = shows['country'].value_counts().head(10)  # Top 10 countries
plt.figure(figsize=(12, 6))
country_distribution.plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries Contributing Content')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis on Directors and Cast

# %% [markdown]
# ### - Top 10 Directors

# %%
top_directors = shows['director'].value_counts().head(11)
top_directors
# Out:
# director
# Unknown                   2538
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Youssef Chahine             12
# Martin Scorsese             12
# Jay Chapman                 12
# Steven Spielberg            11
# Name: count, dtype: int64

# %% [markdown]
# ### Top 10 cast

# %%
top_cast = shows['cast'].str.split(',',expand=True).stack().value_counts().head(10)
top_cast
# Out:
# Unknown              817
#  Anupam Kher          39
#  Rupa Bhimani         31
#  Takahiro Sakurai     29
#  Julie Tejwani        28
#  Om Puri              27
# Shah Rukh Khan        26
#  Rajesh Kava          26
#  Andrea Libman        25
#  Boman Irani          25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=shows, x='rating')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
shows['rating'].unique()
# Out:
# ['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', ..., 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR']
# Length: 14
# Categories (14, object): ['G', 'NC-17', 'NR', 'PG', ..., 'TV-Y', 'TV-Y7', 'TV-Y7-FV', 'UR']

# %% [markdown]
# ### Distribution of Content duration for Movies and Tv Shows

# %%
# Separate movies and TV shows
movies = shows[shows['type'] == 'Movie']
tv_shows = shows[shows['type'] == 'TV Show']
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
# Explore the distribution of content duration
plt.figure(figsize=(12, 6))
plt.hist(movies['duration'].head(50), bins=30, color='skyblue', alpha=0.7, label='Movies')
plt.hist(tv_shows['duration'].head(50), bins=30, color='orange', alpha=0.7, label='TV Shows')
plt.title('Distribution of Content Duration')
plt.xlabel('Duration (Minutes for Movies, Seasons for TV Shows)')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
# Explore the distribution of content across genres
plt.figure(figsize=(12, 8))
genre_distribution = shows['listed_in'].str.split(', ').explode().value_counts().head(15)
sns.barplot(y=genre_distribution.index, x=genre_distribution.values, palette='viridis')
plt.title('Distribution of Content Across Genres')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Relation between Release Year and Rating

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=shows, x='release_year', y='rating')
plt.title('Relationship Between Release Year and Rating')
plt.xlabel('Release Year')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# In this analysis we have done analyzation on what netflix features more
# - Netflix features movies more than Tv shows
# - As the years goes on netflix features movies and Tv shows more.During 1940s it was Between 0-500 while in 2020 it becomes upto 3500
# - Netflix features the contents United states more and second comes India
# - Rajiv chilaka's contents are more features
# - Tv-MA contents have the highest ratings which are for only mature adults
# - The duration for movies are maximum upto 145min and most people have seen the one with duration between 90-160min
# - Tv shows are featured in seasons and it may have 2 or more seasons
# - Genres - most featured netflix genres are  international movies , dramas and comedies respectively and it's highly viewed in netflix
